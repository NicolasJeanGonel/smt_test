# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x):
    return np.abs(x)**(1/2)

# %%
x_test=np.linspace(-10,10,2000)
x_test
y_true=f(x_test)
plt.plot(x_test,y_true)

# %%
# x_sample =np.sort(np.random.rand(100)*20-10)
x_sample=np.linspace(-10,10,200)
y_sample=f(x_sample)
plt.scatter(x_sample,y_sample)

# %%
from smt.surrogate_models import KRG
model=KRG(theta0=[1e-2],print_prediction = False,corr="matern32")
model.set_training_values(x_sample,y_sample)
model.train()
y2=model.predict_values(x_test)
plt.figure()
plt.scatter(x_sample,y_sample,alpha=0.5,marker="x",c="orange")
plt.plot(x_test,y2)
plt.plot(x_test,y_true,alpha=0.5)
# Out:
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 200
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  1.6541631

# %%
model=KRG(theta0=[1],print_prediction = False,corr="squar_exp",eval_noise=False)
model.set_training_values(x_sample,y_sample)
model.train()
y2=model.predict_values(x_test)
plt.figure()
plt.scatter(x_sample,y_sample)
plt.plot(x_test,y2)
plt.plot(x_test,y_true,alpha=0.5)
# Out:
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 200
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\smt\surrogate_models\krg_based.py:968: UserWarning: R is too ill conditioned. Poor combination of regression model and observations.
#   warnings.warn(
#    Training - done. Time (sec):  5.9332638

# %%
model=KRG(theta0=[1e-2],print_prediction = False,corr="abs_exp")
model.set_training_values(x_sample,y_sample)
model.train()
y2=model.predict_values(x_test)
plt.figure()
plt.scatter(x_sample,y_sample)
plt.plot(x_test,y2)
plt.plot(x_test,y_true,alpha=0.5)
# Out:
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 200
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  2.0616696

# %%
def f(x):
    return np.sin(x)

x_test=np.linspace(-10,10,2000)
x_test
y_true=f(x_test)
plt.plot(x_test,y_true)

x_sample=np.linspace(-10,10,200)
y_sample=f(x_sample)
plt.scatter(x_sample,y_sample)

# %%
model=KRG(theta0=[1e-2],print_prediction = False,corr="squar_sin_exp")
model.set_training_values(x_sample,y_sample)
model.train()
y2=model.predict_values(x_test)
plt.figure()
plt.scatter(x_sample,y_sample)
plt.plot(x_test,y2)
plt.plot(x_test,y_true,alpha=0.5)
# Out:
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 200
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\smt\surrogate_models\krg_based.py:968: UserWarning: R is too ill conditioned. Poor combination of regression model and observations.
#   warnings.warn(
# exception :  189-th leading minor of the array is not positive definite
# [ 1.20156199e+02+0.00000000e+00j  3.40868963e+01+0.00000000e+00j
#   3.45875856e+01+0.00000000e+00j  5.07986769e+00+0.00000000e+00j
#   5.01443353e+00+0.00000000e+00j  5.00691337e-01+0.00000000e+00j
#   4.95712763e-01+0.00000000e+00j  3.70935731e-02+0.00000000e+00j
#   3.68913097e-02+0.00000000e+00j  2.20223927e-03+0.00000000e+00j
#   2.19918269e-03+0.00000000e+00j  1.09978108e-04+0.00000000e+00j
#   1.08411618e-04+0.00000000e+00j  4.91648090e-06+0.00000000e+00j
#   4.37403147e-06+0.00000000e+00j  1.74221999e-07+0.00000000e+00j
#   1.70161583e-07+0.00000000e+00j  5.71444853e-09+0.00000000e+00j
#   5.68880090e-09+0.00000000e+00j  1.70254268e-10+0.00000000e+00j
#   1.69711248e-10+0.00000000e+00j  4.64602138e-12+0.00000000e+00j
#   4.60817525e-12+0.00000000e+00j  1.39572123e-13+0.00000000e+00j
#   1.40082297e-13+0.00000000e+00j -7.71119307e-15+0.00000000e+00j
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\smt\surrogate_models\krg_based.py:529, in KrgBased._train(self)
#     524 """
#     525 Train the model
#     526 """
#     527 # outputs['sol'] = self.sol
# --> 529 self._new_train()
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\smt\surrogate_models\krg_based.py:505, in KrgBased._new_train(self)
#     498 self._check_F(n_samples_F, p)
#     500 # Optimization
#     501 (
#     502     self.optimal_rlf_value,
#     503     self.optimal_par,
#     504     self.optimal_theta,
# --> 505 ) = self._optimize_hyperparam(D)
#     506 if self.name in ["MGP"]:
#     507     self._specific_train()
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\smt\surrogate_models\krg_based.py:1970, in KrgBased._optimize_hyperparam(self, D)
#    1968 theta_all_loops = 10**theta_all_loops
#    1969 for theta0_loop in theta_all_loops:
# -> 1970     optimal_theta_res_loop = optimize.minimize(
#    1971         minus_reduced_likelihood_function,
#    1972         theta0_loop,
#    1973         method="TNC",
#    1974         jac=grad_minus_reduced_likelihood_function,
#    1975         ###The hessian information is available but never used
#    1976         #
#    1977         ####hess=hessian_minus_reduced_likelihood_function,
#    1978         bounds=bounds_hyp,
#    1979         options={"maxfun": limit},
#    1980     )
#    1981     if optimal_theta_res_loop["fun"] < optimal_theta_res["fun"]:
#    1982         optimal_theta_res = optimal_theta_res_loop
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\scipy\optimize\_minimize.py:716, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     713     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     714                            callback=callback, **options)
#     715 elif meth == 'tnc':
# --> 716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#     718 elif meth == 'cobyla':
#     719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\scipy\optimize\_tnc.py:417, in _minimize_tnc(fun, x0, args, jac, bounds, eps, scale, offset, mesg_num, maxCGit, eta, stepmx, accuracy, minfev, ftol, xtol, gtol, rescale, disp, callback, finite_diff_rel_step, maxfun, **unknown_options)
#     414 if maxfun is None:
#     415     maxfun = max(100, 10*len(x0))
# --> 417 rc, nf, nit, x, funv, jacv = moduleTNC.tnc_minimize(
#     418     func_and_grad, x0, low, up, scale,
#     419     offset, messages, maxCGit, maxfun,
#     420     eta, stepmx, accuracy, fmin, ftol,
#     421     xtol, pgtol, rescale, callback
#     422 )
#     423 # the TNC documentation states: "On output, x, f and g may be very
#     424 # slightly out of sync because of scaling". Therefore re-evaluate
#     425 # func_and_grad so they are synced.
#     426 funv, jacv = func_and_grad(x)
#
# File _moduleTNC.pyx:200, in _moduleTNC.tnc_minimize()
#
# File _moduleTNC.pyx:72, in _moduleTNC.function()
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\scipy\optimize\_differentiable_functions.py:297, in ScalarFunction.fun_and_grad(self, x)
#     295     self._update_x_impl(x)
#     296 self._update_fun()
# --> 297 self._update_grad()
#     298 return self.f, self.g
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\scipy\optimize\_differentiable_functions.py:267, in ScalarFunction._update_grad(self)
#     265 def _update_grad(self):
#     266     if not self.g_updated:
# --> 267         self._update_grad_impl()
#     268         self.g_updated = True
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\scipy\optimize\_differentiable_functions.py:175, in ScalarFunction.__init__.<locals>.update_grad()
#     174 def update_grad():
# --> 175     self.g = grad_wrapped(self.x)
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\scipy\optimize\_differentiable_functions.py:172, in ScalarFunction.__init__.<locals>.grad_wrapped(x)
#     170 def grad_wrapped(x):
#     171     self.ngev += 1
# --> 172     return np.atleast_1d(grad(np.copy(x), *args))
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\smt\surrogate_models\krg_based.py:1772, in KrgBased._optimize_hyperparam.<locals>.grad_minus_reduced_likelihood_function(log10t)
#    1767 def grad_minus_reduced_likelihood_function(log10t):
#    1768     log10t_2d = np.atleast_2d(log10t).T
#    1769     res = (
#    1770         -np.log(10.0)
#    1771         * (10.0**log10t_2d)
# -> 1772         * (self._reduced_likelihood_gradient(10.0**log10t_2d)[0])
#    1773     )
#    1774     return res
#
# File c:\Users\n.gonel\AppData\Local\anaconda3\envs\smt\Lib\site-packages\smt\surrogate_models\krg_based.py:1080, in KrgBased._reduced_likelihood_gradient(self, theta)
#    1038 """
#    1039 Evaluates the reduced_likelihood_gradient at a set of hyperparameters.
#    1040
#    (...)
#    1076     List of all sigma derivatives
#    1077 """
#    1078 red, par = self._reduced_likelihood_function(theta)
# -> 1080 C = par["C"]
#    1081 gamma = par["gamma"]
#    1082 Q = par["Q"]
#
# KeyError: 'C'
